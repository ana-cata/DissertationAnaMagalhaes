# %%
import csv
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
#%matplotlib inline
# %matplotlib notebook

# %%
A1 = "20210714-150307_peixe1.csv"
A2 = "20210714-152517_peixe2.csv"
A3_1 = "20210714-155358_peixe3.1.csv"
A3_2 = "20210714-160833_peixe3.2.csv"
A4 = "20210714-162911_peixe4.csv"

data=pd.read_csv(A1)
fish_number = 1
bn = 17
fn = 950

data.columns = ['Tempo','Amplitude', 'Temperatura']

print(data)

begin= int(bn/0.01)- int(10.92/0.01)
finish = int(fn/0.01)- int(10.92/0.01)
# Out:
#         Tempo  Amplitude  Temperatura
# 0       15.64       4701        25.08
# 1       15.65       4650        25.08
# 2       15.66       4703        24.98
# 3       15.67       4643        25.08
# 4       15.68       4702        25.08
# ...       ...        ...          ...
# 93646  952.72       4817        24.58
# 93647  952.73       4807        24.58
# 93648  952.74       4815        24.58
# 93649  952.75       4811        24.58
# 93650  952.76       4783        24.58
#
# [93651 rows x 3 columns]

# %%
# z = np.polyfit(data['Tempo'], data['Temperatura'], 1)
# p = np.poly1d(z)
# thermistor_erro = 0.2
# y_min1 = []
# y_max1 =[]
# for m1 in range(0, len(data['Tempo'])):
#     y_min1.append(p(data['Tempo'][m1]) - thermistor_erro)         
#     y_max1.append(p(data['Tempo'][m1]) + thermistor_erro)


# plt.plot(data['Tempo'],p(data['Tempo']),'b--',color='C1', label='Water temperature')
# plt.fill_between(data['Tempo'], y_min1, y_max1,  color='C1', alpha=0.5)
# plt.ylim([23.8,25.75])
plt.plot(data['Tempo'], data['Temperatura'], 'ko')
plt.xlabel('Time (s)')
plt.ylabel('Temperature ($^\circ$C)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
